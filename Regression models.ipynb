# %% [markdown]
# # Checkpoint3 : First Step into machine Learning : regression models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# %%
house_data=pd.read_csv("house_data.csv", encoding='ISO-8859-1')

# %%
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
print(house_data.isnull().any().sum(), ' / ', len(house_data.columns))
print(house_data.isnull().any(axis=1).sum(), ' / ', len(house_data))
# Out:
# 0  /  21
# 0  /  21613

# %%
corr = house_data.corr()

s , ax = plt.subplots( figsize =( 20 , 18 ) )

cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })

# %% [markdown]
# We use the correlation to selection the most important feature to predict the price <br />
# Through this matrix we can see that the price is highly correlated respectively with : "sqft_living", "grade", "sqft_above", "sqft_living15" , "bathrooms"

# %%
data = pd.concat([house_data['price'], house_data['sqft_living']], axis=1)
data.plot.scatter(x='sqft_living', y='price', ylim=(3,9000000))
plt.show()

# %%
data = pd.concat([house_data['price'], house_data['sqft_above']], axis=1)
data.plot.scatter(x='sqft_above', y='price', ylim=(3,9000000))
plt.show()

# %%
data = pd.concat([house_data['price'], house_data['sqft_living15']], axis=1)
data.plot.scatter(x='sqft_living15', y='price', ylim=(3,9000000))
plt.show()

# %%
data = pd.concat([house_data['price'], house_data['grade']], axis=1)
f, ax = plt.subplots(figsize=(20, 20))
fig = sns.boxplot(x='grade', y="price", data=data)
fig.axis(ymin=0, ymax=6000000)
# Out:
# (-0.5, 11.5, 0, 6000000)

# %%
data = pd.concat([house_data['price'], house_data['bathrooms']], axis=1)
f, ax = plt.subplots(figsize=(20, 20))
fig = sns.boxplot(x='bathrooms', y="price", data=data)
fig.axis(ymin=0, ymax=6000000)
# Out:
# (-0.5, 29.5, 0, 6000000)

# %%
sns.set()
cols = ['price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms']
sns.pairplot(house_data[cols], height = 3.5)
plt.show()

# %%
new_data = house_data[['sqft_living','grade', 'sqft_above', 'sqft_living15','bathrooms']]
X = new_data.values
y = house_data.price.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2, random_state=30)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
predicted=model.predict(X_test)
print('MSE', mean_squared_error(y_test,predicted))
print('R squared', metrics.r2_score(y_test,predicted))
# Out:
# MSE 56785447189.6633
# R squared 0.5469717819161903

# %%
model.coef_
# Out:
# array([ 2.51232479e+02,  1.08061128e+05, -8.49027788e+01,  2.79298053e+01,
#        -3.58110969e+04])

# %%
model.intercept_
# Out:
# -637288.7977819698

# %%
poly=PolynomialFeatures(degree=3)
X_train_fit=poly.fit_transform(X_test)
model.fit(X_train,y_train)
x_test_=poly.fit_transform(X_test)
predicted=model.predict(X_test)
print('MSE', mean_squared_error(y_test,predicted))
print('R squared', metrics.r2_score(y_test,predicted))
# Out:
# MSE 56785447189.6633
# R squared 0.5469717819161903

# %% [markdown]
# #Results of Polynomial regression multilinear regression are same according to this results
